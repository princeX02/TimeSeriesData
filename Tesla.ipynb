# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Download Tesla stock data
tsla_data = yf.download('TSLA', start='2002-01-01', end='2025-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Display the first few rows
print(tsla_data.head(10))
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500
# 2010-07-07  1.053333  1.108667  0.998667  1.093333  103825500
# 2010-07-08  1.164000  1.168000  1.038000  1.076000  115671000
# 2010-07-09  1.160000  1.193333  1.103333  1.172000   60759000
# 2010-07-12  1.136667  1.204667  1.133333  1.196667   33037500
# 2010-07-13  1.209333  1.242667  1.126667  1.159333   40201500

# %% [markdown]
# typeof(tsla_data)

# %%
type(tsla_data)
# Out:
# pandas.core.frame.DataFrame

# %%
tsla_data.head(4)
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000

# %%
tsla_data.tail(5)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2024-12-24  462.279999  462.779999  435.140015  435.899994  59551800
# 2024-12-26  454.130005  465.329987  451.019989  465.160004  76366400
# 2024-12-27  431.660004  450.000000  426.500000  449.519989  82666800
# 2024-12-30  417.410004  427.000000  415.750000  419.399994  64941000
# 2024-12-31  403.839996  427.929993  402.540009  423.790009  76825100

# %%
tsla_data.size
# Out:
# 18260

# %%
tsla_data.shape
# Out:
# (3652, 5)

# %%
tsla_data['High'].plot(figsize=(15,10))
plt.title("High Prices")
plt.show()

# %%
tsla_data['Low'].plot(figsize=(15,10))
plt.title("Low Prices")
plt.show()

# %%
#xlimit and ylimit and coloring
tsla_data['High'].plot(xlim=['2020-01-10','2025-01-01'] ,ylim=[100,500],figsize=(15,8),c='red',ls='-')
plt.title("High Prices")
plt.show()

# %%
tsla_data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2010-06-29    1.592667    1.666667    1.169333    1.266667  281494500
# 2010-06-30    1.588667    2.028000    1.553333    1.719333  257806500
# 2010-07-01    1.464000    1.728000    1.351333    1.666667  123282000
# 2010-07-02    1.280000    1.540000    1.247333    1.533333   77097000
# 2010-07-06    1.074000    1.333333    1.055333    1.333333  103003500
# ...                ...         ...         ...         ...        ...
# 2024-12-24  462.279999  462.779999  435.140015  435.899994   59551800
# 2024-12-26  454.130005  465.329987  451.019989  465.160004   76366400
# 2024-12-27  431.660004  450.000000  426.500000  449.519989   82666800
# 2024-12-30  417.410004  427.000000  415.750000  419.399994   64941000
# 2024-12-31  403.839996  427.929993  402.540009  423.790009   76825100
#
# [3652 rows x 5 columns]

# %%
index=tsla_data.loc['2010-06-29':'2014-07-6']
share_open=tsla_data.loc['2010-06-29':'2014-07-6']['Open']

# %%
share_open
# Out:
# Ticker           TSLA
# Date
# 2010-06-29   1.266667
# 2010-06-30   1.719333
# 2010-07-01   1.666667
# 2010-07-02   1.533333
# 2010-07-06   1.333333
# ...               ...
# 2014-06-27  15.646000
# 2014-06-30  15.970000
# 2014-07-01  16.164000
# 2014-07-02  16.044001
# 2014-07-03  15.419333
#
# [1011 rows x 1 columns]

# %%
figure,axis=plt.subplots()

plt.tight_layout()
axis.plot(index,share_open)
plt.show()

# %%
tsla_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3652 entries, 2010-06-29 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, TSLA)   3652 non-null   float64
#  1   (High, TSLA)    3652 non-null   float64
#  2   (Low, TSLA)     3652 non-null   float64
#  3   (Open, TSLA)    3652 non-null   float64
#  4   (Volume, TSLA)  3652 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 300.2 KB

# %%
from datetime import datetime
from datetime import date

# %%
datetime(2021,11,21,0,0)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 4, 19, 18, 52, 7, 807132)

# %%
def add_num(num1,num2):
    return num1+num2

# %%
start_time=datetime.now()
add_num(10,12)
end_time=datetime.now()
print(start_time,end_time)
# Out:
# 2025-04-19 18:52:08.431007 2025-04-19 18:52:08.431054

# %% [markdown]
# #Time  Reshempling

# %%
tsla_data.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
tsla_data.resample(rule='A').min()
# Out:
# /var/folders/8t/1xgb90cn3ns84sssmr9z_bf40000gn/T/ipykernel_26558/2244550732.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   tsla_data.resample(rule='A').min()
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2010-12-31    1.053333    1.108667    0.998667    1.076000   1777500
# 2011-12-31    1.455333    1.484667    1.407333    1.452000   3594000
# 2012-12-31    1.519333    1.790000    1.509333    1.774667   5473500
# 2013-12-31    2.194000    2.225333    2.140667    2.205333   6603000
# 2014-12-31    9.289333    9.800000    9.111333    9.366667  19983000
# 2015-12-31   12.333333   12.619333   12.093333   12.388667  10620000
# 2016-12-31    9.578000   10.331333    9.403333    9.488000  24892500
# 2017-12-31   14.466000   14.688667   14.064000   14.316667  32800500
# ...

# %%
tsla_data.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
tsla_data.resample(rule='BA').max()
# Out:
# /var/folders/8t/1xgb90cn3ns84sssmr9z_bf40000gn/T/ipykernel_26558/2360944576.py:1: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   tsla_data.resample(rule='BA').max()
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2010-12-31    2.364667    2.428000    2.316667    2.391333  281494500
# 2011-12-30    2.329333    2.333333    2.268667    2.308667  172767000
# 2012-12-31    2.534000    2.663333    2.474000    2.546000   85206000
# 2013-12-31   12.891333   12.966667   12.558000   12.930667  557458500
# 2014-12-31   19.069332   19.427999   18.693333   19.177999  490225500
# 2015-12-31   18.817333   19.110001   18.420000   18.680000  234744000
# 2016-12-30   17.694668   17.955999   16.967333   17.763332  356136000
# 2017-12-29   25.666668   25.974001   25.290001   25.779333  296871000
# ...

# %%
tsla_data['Open'].resample(rule='M').mean()
# Out:
# /var/folders/8t/1xgb90cn3ns84sssmr9z_bf40000gn/T/ipykernel_26558/2433027442.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   tsla_data['Open'].resample(rule='M').mean()
# Ticker            TSLA
# Date
# 2010-06-30    1.493000
# 2010-07-31    1.338222
# 2010-08-31    1.303030
# 2010-09-30    1.385270
# 2010-10-31    1.381556
# ...                ...
# 2024-08-31  209.370911
# 2024-09-30  234.301501
# 2024-10-31  239.483479
# 2024-11-30  318.260001
# 2024-12-31  415.473809
#
# [175 rows x 1 columns]

# %%
tsla_data['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# /var/folders/8t/1xgb90cn3ns84sssmr9z_bf40000gn/T/ipykernel_26558/1958126507.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   tsla_data['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# <Axes: xlabel='Date'>

# %%
tsla_data['High'].rolling(10).mean().head(20)
# Out:
# Ticker          TSLA
# Date
# 2010-06-29       NaN
# 2010-06-30       NaN
# 2010-07-01       NaN
# 2010-07-02       NaN
# 2010-07-06       NaN
# 2010-07-07       NaN
# 2010-07-08       NaN
# 2010-07-09       NaN
# 2010-07-12       NaN
# 2010-07-13  1.421333
# 2010-07-14  1.389000
# 2010-07-15  1.329533
# 2010-07-16  1.298733
# 2010-07-19  1.293067
# 2010-07-20  1.305400
# 2010-07-21  1.333867
# 2010-07-22  1.358733
# 2010-07-23  1.383133
# 2010-07-26  1.406000
# 2010-07-27  1.422933

# %%
tsla_data['High'].head(20)
# Out:
# Ticker          TSLA
# Date
# 2010-06-29  1.666667
# 2010-06-30  2.028000
# 2010-07-01  1.728000
# 2010-07-02  1.540000
# 2010-07-06  1.333333
# 2010-07-07  1.108667
# 2010-07-08  1.168000
# 2010-07-09  1.193333
# 2010-07-12  1.204667
# 2010-07-13  1.242667
# 2010-07-14  1.343333
# 2010-07-15  1.433333
# 2010-07-16  1.420000
# 2010-07-19  1.483333
# 2010-07-20  1.456667
# 2010-07-21  1.393333
# 2010-07-22  1.416667
# 2010-07-23  1.437333
# 2010-07-26  1.433333
# 2010-07-27  1.412000

# %%
tsla_data['30 Days Roalling']=tsla_data['Open'].rolling(30).mean()

# %%
tsla_data.head(35)
# Out:
# Price          Close      High       Low      Open     Volume 30 Days Roalling
# Ticker          TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500              NaN
# 2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500              NaN
# 2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000              NaN
# 2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000              NaN
# 2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500              NaN
# 2010-07-07  1.053333  1.108667  0.998667  1.093333  103825500              NaN
# 2010-07-08  1.164000  1.168000  1.038000  1.076000  115671000              NaN
# 2010-07-09  1.160000  1.193333  1.103333  1.172000   60759000              NaN
# 2010-07-12  1.136667  1.204667  1.133333  1.196667   33037500              NaN
# 2010-07-13  1.209333  1.242667  1.126667  1.159333   40201500              NaN
# ...

# %%
tsla_data[['Open','30 Days Roalling']].plot(figsize=(15,10))
# Out:
# <Axes: xlabel='Date'>
